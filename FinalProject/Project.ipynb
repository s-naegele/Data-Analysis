# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
# %matplotlib inline

# %%
athletes = pd.read_csv('athlete_events.csv')
athletes.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.set_geometry('geometry')
world.plot(figsize=(10,10))
plt.show()

# %%
NOC = pd.read_csv('noc_regions.csv')
NOC.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
merge1980 = world.set_index('iso_a3').join(year1980.set_index('NOC'))
merge1980.head()
# Out:
#               pop_est   continent iso_a3  gdp_md_est  \
# Afghanistan  34124811        Asia    AFG     64080.0
# Albania       3047987      Europe    ALB     33900.0
# Algeria      40969443      Africa    DZA    609400.0
# Angola       29310273      Africa    AGO    189000.0
# Antarctica       4050  Antarctica    ATA       810.0
#
#                                                       geometry  NOC notes
# Afghanistan  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  AFG   NaN
# Albania      POLYGON ((21.02004 40.84273, 20.99999 40.58000...  ALB   NaN
# Algeria      POLYGON ((-8.68440 27.39574, -8.66512 27.58948...  ALG   NaN
# Angola       MULTIPOLYGON (((12.99552 -4.78110, 12.63161 -4...  ANG   NaN
# Antarctica   MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...  NaN   NaN

# %%
year1980 = athletes[athletes['Year'] == 1980]
merge1980 = mergeNocWorld.set_index('iso_a3').join(year1980.set_index('NOC'))
merge1980.head()
# Out:
#       pop_est continent  gdp_md_est  \
# -99  67106161    Europe   2699000.0
# -99   1895250    Europe     18490.0
# -99    265100      Asia      3600.0
# -99   5320045    Europe    364700.0
# -99   3500000    Africa     12250.0
#
#                                               geometry  NOC notes  ID Name  \
# -99  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...  FRA   NaN NaN  NaN
# -99  POLYGON ((20.59025 41.85541, 20.52295 42.21787...  KOS   NaN NaN  NaN
# -99  POLYGON ((32.73178 35.14003, 32.80247 35.14550...  NaN   NaN NaN  NaN
# -99  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...  NOR   NaN NaN  NaN
# -99  POLYGON ((48.94820 11.41062, 48.94820 11.41062...  NaN   NaN NaN  NaN
#
#      Sex  Age  Height  Weight Team Games  Year Season City Sport Event Medal
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN

# %%
merge1980.plot(column='Team',figsize=(50,10), cmap= 'inferno', legend=True )
# Out:
# <AxesSubplot:>

# %%
year1984 = athletes[athletes['Year'] == 1984]
merge1984 = mergeNocWorld.set_index('iso_a3').join(year1984.set_index('NOC'))
merge1984.head()
# Out:
#       pop_est continent  gdp_md_est  \
# -99  67106161    Europe   2699000.0
# -99   1895250    Europe     18490.0
# -99    265100      Asia      3600.0
# -99   5320045    Europe    364700.0
# -99   3500000    Africa     12250.0
#
#                                               geometry  NOC notes  ID Name  \
# -99  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...  FRA   NaN NaN  NaN
# -99  POLYGON ((20.59025 41.85541, 20.52295 42.21787...  KOS   NaN NaN  NaN
# -99  POLYGON ((32.73178 35.14003, 32.80247 35.14550...  NaN   NaN NaN  NaN
# -99  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...  NOR   NaN NaN  NaN
# -99  POLYGON ((48.94820 11.41062, 48.94820 11.41062...  NaN   NaN NaN  NaN
#
#      Sex  Age  Height  Weight Team Games  Year Season City Sport Event Medal
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN
# -99  NaN  NaN     NaN     NaN  NaN   NaN   NaN    NaN  NaN   NaN   NaN   NaN

# %%
merge1984.plot(column='Team',figsize=(50,10), cmap= 'inferno', legend=True )
# Out:
# <AxesSubplot:>

# %%
merge1984.plot(column='Team',figsize=(50,10), cmap= 'inferno', legend=True )
# Out:
# <AxesSubplot:>

# %%
merge1980 = world.set_index('iso_a3').join(year1980.set_index('NOC'))
merge1980.plot(column='Team',figsize=(50,10), cmap= 'inferno', legend=True )
# Out:
# <AxesSubplot:>
